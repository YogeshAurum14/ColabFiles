# %%
import PyPDF2

# %%
pdfFileObj = open('Untitled document.pdf', 'rb')

# %%
pwd
# Out:
# 'C:\\Users\\Admin'

# %%
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
print(pdfReader.numPages)
# Out:
# 3

# %%
pageObj = pdfReader.getPage(0)

# %%
print(pageObj.extractText())

# %%
pdfFileObj = open('msg_sample_doc.pdf', 'rb')

# %%
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
print(pdfReader.numPages)
pageObj = pdfReader.getPage(0)
print(pageObj.extractText())
# Out:
# 1

# %%
pageObj
# Out:
# {'/Contents': {'/Filter': '/FlateDecode'},
#  '/MediaBox': [0, 0, 596, 843],
#  '/Parent': {'/Count': 1, '/Kids': [IndirectObject(6, 0)], '/Type': '/Pages'},
#  '/Resources': {'/ExtGState': {'/G3': {'/BM': '/Normal', '/ca': 1},
#    '/G4': {'/BM': '/Normal', '/ca': 0}},
#   '/Font': {'/F5': {'/BaseFont': '/ArialMT',
#     '/DescendantFonts': [IndirectObject(17, 0)],
#     '/Encoding': '/Identity-H',
#     '/Subtype': '/Type0',
#     '/ToUnicode': {'/Filter': '/FlateDecode'},
#     '/Type': '/Font'}},
#   '/ProcSet': ['/PDF', '/Text', '/ImageB', '/ImageC', '/ImageI']},
#  '/StructParents': 0,
#  '/Type': '/Page'}

# %%
for i in pageObj.extractText():
    print(i)

# %%
msg_string= """
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.265.00 on 11-10-2019 01:25:48 and credited to VPA amazon@apl (UPI Ref no 928401866301)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.5613.67 on 25-10-2019 10:12:47 and credited to VPA paytm-irctcapp@paytm (UPI Ref no 929846066239)
Your A/c XXXX604 is DR for INR 5,613.67 on 25/10/19 22:12:47  UPI/IRCTC App UPI/PYTM0123456/. Clear bal is INR 3,432.92 CR. For details contact home branch OR 02241572070.
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.130.00 on 31-10-2019 01:44:07 and credited to VPA add-money@paytm (UPI Ref no 930413404671)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.159.00 on 31-10-2019 03:20:53 and credited to VPA jio@citibank (UPI Ref no 930415629114)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.444.00 on 02-11-2019 10:17:16 and credited to VPA jio@citibank (UPI Ref no 930610230380)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.547.00 on 04-11-2019 10:17:28 and credited to VPA amazonpay@apl (UPI Ref no 930810880902)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.951.00 on 04-11-2019 12:55:16 and credited to VPA amazon@apl (UPI Ref no 930812149545)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.458.00 on 07-11-2019 08:45:44 and credited to VPA vmslprepaid@hsbc (UPI Ref no 931111305892)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.14.00 on 07-11-2019 10:17:34 and credited to VPA Q61090030@ybl (UPI Ref no 931140475908)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.300.00 on 08-11-2019 03:34:40 and credited to VPA paytmqr28100505010119lcpfvsp0n3@paytm (UPI Ref no 931215953552)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.40.00 on 09-11-2019 10:57:10 and credited to VPA AMZN0000406852@apl (UPI Ref no 931322501416)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.409.00 on 11-11-2019 12:04:47 and credited to VPA jio@citibank (UPI Ref no 931500573532)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.250.00 on 12-11-2019 05:23:10 and credited to VPA vatsayush16@oksbi (UPI Ref no 931617174084)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.10446.00 on 13-11-2019 10:11:21 and credited to VPA amazon@apl (UPI Ref no 931710764118)
Your A/c XXXX604 is DR for INR 10,446.00 on 13/11/19 10:11:21  UPI/AMAZON/UTIB0000100/1000129. Clear bal is INR 1,260.90 CR. For details contact home branch OR 02241572070.
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.500.00 on 15-11-2019 10:19:00 and credited to VPA richaagarwal7886@okaxis (UPI Ref no 931910161235)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.130.00 on 15-11-2019 08:17:13 and credited to VPA saurabhjha57@okhdfcbank (UPI Ref no 931920235787)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.70.00 on 15-11-2019 11:06:56 and credited to VPA aakashdoke92@okhdfcbank (UPI Ref no 931923947382)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.160.00 on 16-11-2019 07:34:33 and credited to VPA bharatpe.9040099170@icici (UPI Ref no 932019333909)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.180.00 on 20-11-2019 12:30:00 and credited to VPA q15497530@ybl (UPI Ref no 932412842782)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.575.00 on 20-11-2019 05:46:50 and credited to VPA paytmqr281005050101xsrl8v6tpw0o@paytm (UPI Ref no 932417378059)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.3400.00 on 02-12-2019 09:10:11 and credited to VPA 8108981027@ybl (UPI Ref no 933684458245)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.210.00 on 03-12-2019 02:15:35 and credited to VPA 9833279599@ybl (UPI Ref no 933756687680)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.210.00 on 03-12-2019 02:15:53 and credited to VPA 9833279599@ybl (UPI Ref no 933742643638)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.210.00 on 03-12-2019 02:16:50 and credited to VPA tempttsttation@okhdfcbank (UPI Ref no 933714912288)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.35.00 on 03-12-2019 05:49:24 and credited to VPA BHARATPE09600003854@yesbankltd (UPI Ref no 933717545526)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.30.00 on 05-12-2019 08:08:59 and credited to VPA AMZN0003007087@apl (UPI Ref no 933920792446)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.375.00 on 08-12-2019 09:10:33 and credited to VPA AMZN0001747582@apl (UPI Ref no 934221266791)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.376.00 on 08-12-2019 09:39:36 and credited to VPA amazon@apl (UPI Ref no 934221390323)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.30.00 on 10-12-2019 10:31:06 and credited to VPA paytmqr2810050501019z0qmvs5sndf@paytm (UPI Ref no 934422313006)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.48.00 on 12-12-2019 03:07:31 and credited to VPA BHARATPE90718282763@yesbankltd (UPI Ref no 934615741482)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.149.00 on 22-12-2019 06:43:18 and credited to VPA billdesk.reliance-jio-prepaid@icici (UPI Ref no 935618499104)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.199.00 on 23-12-2019 10:58:18 and credited to VPA billdesk.reliance-jio-prepaid@icici (UPI Ref no 935722039624)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.400.00 on 23-12-2019 10:59:59 and credited to VPA kuldeeppathak3@ybl (UPI Ref no 935744174946)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.400.00 on 23-12-2019 11:02:08 and credited to VPA kuldeepp419@oksbi (UPI Ref no 935723048693)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.100.00 on 23-12-2019 11:52:30 and credited to VPA vs6332800@okaxis (UPI Ref no 935723152316)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.555.00 on 27-12-2019 06:34:26 and credited to VPA BILLDESKPP@ybl (UPI Ref no 936154466203)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.500.00 on 30-12-2019 08:19:05 and credited to VPA 9892778562@upi (UPI Ref no 936440254965)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.30.00 on 31-12-2019 01:01:54 and credited to VPA paytmqr281005050101h4gpwewme679@paytm (UPI Ref no 936513202314)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.3068.00 on 02-01-2020 11:16:28 and credited to VPA 8108981027@ybl (UPI Ref no 000269437326)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.70.00 on 03-01-2020 04:43:31 and credited to VPA paytmqr2810050501011wbxclcuweiy@paytm (UPI Ref no 000316013477)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.140.00 on 03-01-2020 09:37:44 and credited to VPA 8850428483@okbizaxis (UPI Ref no 000321959019)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.4048.00 on 04-01-2020 09:55:55 and credited to VPA lic.billdesk@hdfcbank (UPI Ref no 000409330980)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.12.00 on 05-01-2020 10:58:50 and credited to VPA 8454894765@okbizaxis (UPI Ref no 000510008453)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.1.00 on 05-01-2020 04:34:18 and credited to VPA 9920406061@ybl (UPI Ref no 000516592580)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.300.00 on 05-01-2020 05:29:58 and credited to VPA 9820163044@ybl (UPI Ref no 000568821561)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.100.00 on 05-01-2020 05:34:25 and credited to VPA 9820163044@ybl (UPI Ref no 000534149723)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.114.00 on 05-01-2020 05:36:14 and credited to VPA 9820163044@ybl (UPI Ref no 000534467034)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.322.00 on 05-01-2020 09:41:20 and credited to VPA amazon@apl (UPI Ref no 000521103202)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.200.00 on 06-01-2020 03:33:53 and credited to VPA omkarchavan177@okaxis (UPI Ref no 000615706413)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.30.00 on 06-01-2020 07:36:06 and credited to VPA 9867423444@okbizaxis (UPI Ref no 000619239613)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.25.00 on 06-01-2020 09:19:27 and credited to VPA 9137864657@okbizaxis (UPI Ref no 000621408217)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.1000.00 on 07-01-2020 10:45:01 and credited to VPA diadubey14@okicici (UPI Ref no 000710524892)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.12.00 on 09-01-2020 12:55:37 and credited to VPA 8825237395@okbizaxis (UPI Ref no 000912177683)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.30.00 on 10-01-2020 11:15:13 and credited to VPA paytmqr281005050101daypnw7ix1d9@paytm (UPI Ref no 001011672618)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.200.00 on 10-01-2020 01:56:36 and credited to VPA diadubey14@okicici (UPI Ref no 001013510921)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.40.00 on 11-01-2020 02:14:16 and credited to VPA paytm-8796946@paytm (UPI Ref no 001114548677)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.300.00 on 11-01-2020 06:17:03 and credited to VPA amanprakash569@okicici (UPI Ref no 001118378797)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.200.00 on 13-01-2020 01:52:50 and credited to VPA diadubey14@okicici (UPI Ref no 001313697859)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.34.00 on 13-01-2020 04:54:14 and credited to VPA paytmqr2810050501011dgci5uzurou@paytm (UPI Ref no 001316738196)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.90.00 on 13-01-2020 07:05:03 and credited to VPA q69042489@ybl (UPI Ref no 001319556491)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.40.00 on 13-01-2020 07:08:30 and credited to VPA q69042489@ybl (UPI Ref no 001319582282)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.120.00 on 03-07-2020 08:21:41 and credited to VPA sameerranjan999@okaxis (UPI Ref no 018520434573)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.3099.09 on 04-07-2020 10:04:06 and credited to VPA paytm-irctcapp@paytm (UPI Ref no 018648421453)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.199.00 on 04-07-2020 06:59:57 and credited to VPA mobikwikp2m@hdfcbank (UPI Ref no 018618821517)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.149.00 on 06-07-2020 09:42:22 and credited to VPA billdesk.reliance-jio-prepaid@icici (UPI Ref no 018821778969)
Your a/c no. XXXXXXXXXXX0604 is debited for Rs.95.00 on 07-07-2020 11:10:42 and credited to VPA paytmqr28100505010114w6b2bkne1u@paytm (UPI Ref no 018911410786)
"""

# %%
msg_string
# Out:
# '\nYour a/c no. XXXXXXXXXXX0604 is debited for Rs.265.00 on 11-10-2019 01:25:48 and credited to VPA amazon@apl (UPI Ref no 928401866301)\nYour a/c no. XXXXXXXXXXX0604 is debited for Rs.5613.67 on 25-10-2019 10:12:47 and credited to VPA paytm-irctcapp@paytm (UPI Ref no 929846066239)\nYour A/c XXXX604 is DR for INR 5,613.67 on 25/10/19 22:12:47  UPI/IRCTC App UPI/PYTM0123456/. Clear bal is INR 3,432.92 CR. For details contact home branch OR 02241572070.\nYour a/c no. XXXXXXXXXXX0604 is debited for Rs.130.00 on 31-10-2019 01:44:07 and credited to VPA add-money@paytm (UPI Ref no 930413404671)\nYour a/c no. XXXXXXXXXXX0604 is debited for Rs.159.00 on 31-10-2019 03:20:53 and credited to VPA jio@citibank (UPI Ref no 930415629114)\nYour a/c no. XXXXXXXXXXX0604 is debited for Rs.444.00 on 02-11-2019 10:17:16 and credited to VPA jio@citibank (UPI Ref no 930610230380)\nYour a/c no. XXXXXXXXXXX0604 is debited for Rs.547.00 on 04-11-2019 10:17:28 and credited to VPA amazonpay@apl (UPI Ref no 9308
# ...

# %%
list1 = []
list1.append(msg_string.split("\n"))

# %%
len(list1[0][:])
# Out:
# 70

# %%
list1[0][1]
# Out:
# 'Your a/c no. XXXXXXXXXXX0604 is debited for Rs.265.00 on 11-10-2019 01:25:48 and credited to VPA amazon@apl (UPI Ref no 928401866301)'

# %%
print_start = ""
list2 = []
for i in range(len(list1[0][:])):
    for b in range(len(list1[0][i][:])):
        list2.append(list1[0][i][:])

# %%
list3=[]
for i in range(len(list2)):
    list3.append(list2[i].split())

# %%
list2[:]
# Out:
# ['Your a/c no. XXXXXXXXXXX0604 is debited for Rs.265.00 on 11-10-2019 01:25:48 and credited to VPA amazon@apl (UPI Ref no 928401866301)',
#  'Your a/c no. XXXXXXXXXXX0604 is debited for Rs.265.00 on 11-10-2019 01:25:48 and credited to VPA amazon@apl (UPI Ref no 928401866301)',
#  'Your a/c no. XXXXXXXXXXX0604 is debited for Rs.265.00 on 11-10-2019 01:25:48 and credited to VPA amazon@apl (UPI Ref no 928401866301)',
#  'Your a/c no. XXXXXXXXXXX0604 is debited for Rs.265.00 on 11-10-2019 01:25:48 and credited to VPA amazon@apl (UPI Ref no 928401866301)',
#  'Your a/c no. XXXXXXXXXXX0604 is debited for Rs.265.00 on 11-10-2019 01:25:48 and credited to VPA amazon@apl (UPI Ref no 928401866301)',
#  'Your a/c no. XXXXXXXXXXX0604 is debited for Rs.265.00 on 11-10-2019 01:25:48 and credited to VPA amazon@apl (UPI Ref no 928401866301)',
#  'Your a/c no. XXXXXXXXXXX0604 is debited for Rs.265.00 on 11-10-2019 01:25:48 and credited to VPA amazon@apl (UPI Ref no 928401866301)',
# ...

# %%
list3[70][5]
# Out:
# 'debited'

# %%
count_credit=0
count_debit=0
for i in range(len(list3)):
    for y in range(len(list3[i][:])):
#         print(list3[i][y])
        if(list3[i][y]=="credited"):
            count_credit += 1
        elif(list3[i][y]=="debited"):
            count_debit+=1
        else:
            continue
print(count_credit)
print(count_debit)
# Out:
# 9448
# 9448

# %%
import re

# %%
# x = re.search(r"\bS\w+", txt)
w=[]
acnt_dict = dict()
print(type(acnt_dict))
for i in range(len(list2)):
    x = re.search(r"\bX\w+",list2[i])
    w.append(x.group())

for i in w:
    acnt_dict[i] = acnt_dict.get(i,0)+1
print(acnt_dict)
# Out:
# <class 'dict'>
# {'XXXXXXXXXXX0604': 9448, 'XXXX604': 343}

# %%
pwd
# Out:
# 'C:\\Users\\Admin'
